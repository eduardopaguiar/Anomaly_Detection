# %%
import numpy as np
from scipy.spatial.distance import pdist, cdist, squareform
from math import sqrt
from numba import njit,jit

# %%
@njit
def chessboard_division_njit(Uniquesample, MMtypicality, interval1, interval2, distancetype):
    L, W = Uniquesample.shape
    if distancetype == 'euclidean':
        W = 1

    BOX = [Uniquesample[k] for k in range(W)]
    BOX_miu = [Uniquesample[k] for k in range(W)]
    BOX_S = [1]*W
    BOX_X = [np.sum(Uniquesample[k]**2) for k in range(W)]
    NB = W
    BOXMT = [MMtypicality[k] for k in range(W)]

    for i in range(W,L):
        XA = Uniquesample[i].reshape(1,-1)
        XB = BOX_miu
        a = []
        for ii in range (len(XA)):
            aux2 = []
            for j in range (len(XB)):
                aux1 = []
                bux1 = 0 
                for e1, e2 in zip(XB[j],XA[ii,:]):
                    aux1.append((e1-e2)**2)
                    bux1 += ((e1-e2)**2)
                aux2.append(bux1**(0.5))
            a.append(aux2)
            
        b = []
        for ii in range(len(XA)):
            aux1 = []
            for j in range(len(XB)):
                dot = 0
                denom_a = 0
                denom_b = 0
                for k in range (len(XB[j])):
                    dot += (XB[j][k]*XA[ii,k])
                    denom_a += (XB[j][k] * XB[j][k])
                    denom_b += (XA[ii,k] * XA[ii,k])

                aux1.append((1 - ((dot / ((denom_a ** 0.5) * (denom_b ** 0.5)))))**0.5)
            b.append(aux1)
        distance = np.array([a[0],b[0]]).T
        
        SQ = []
        for j,d in enumerate(distance):
            if d[0] < interval1 and d[1] < interval2:
                SQ.append(j)
        COUNT = len(SQ)

        if COUNT == 0:
            BOX.append(Uniquesample[i])
            NB = NB + 1
            BOX_S.append(1)
            BOX_miu.append(Uniquesample[i])
            BOX_X.append(np.sum(Uniquesample[i]**2))
            BOXMT.append(MMtypicality[i])

        if COUNT >= 1:
            DIS = [distance[S,0]/interval1[0] + distance[S,1]/interval2[0] for S in SQ]
            b = 0
            mini = DIS[0]
            for ii in range(1,len(DIS)):
                if DIS[ii] < mini:
                    mini = DIS[ii]
                    b = ii
            BOX_S[SQ[b]] = BOX_S[SQ[b]] + 1
            BOX_miu[SQ[b]] = (BOX_S[SQ[b]]-1)/BOX_S[SQ[b]]*BOX_miu[SQ[b]] + Uniquesample[i]/BOX_S[SQ[b]]
            BOX_X[SQ[b]] = (BOX_S[SQ[b]]-1)/BOX_S[SQ[b]]*BOX_X[SQ[b]] + np.sum(Uniquesample[i]**2)/BOX_S[SQ[b]]
            BOXMT[SQ[b]] = BOXMT[SQ[b]] + MMtypicality[i] 
            
        print('_'*30)
    return BOX, BOX_miu, BOX_X, BOX_S, BOXMT, NB

# %%
Uniquesample = np.array(([1.,2.,3.],[1.,5.,7.],[3.,8.,9.]))
MMtypicality = np.array(([43,29,30]))
distancetype = 'euclidean'
interval1 = np.array([6.86690614])
interval2 = np.array([0.99159042])

# %%
# %%time
chessboard_division_njit(Uniquesample, MMtypicality, interval1, interval2, distancetype)
# Out:
# iteraçao
# 1
# [1. 5. 7.]
# [array([1., 2., 3.])]
# [0]
# 1
# [array([1. , 3.5, 5. ])]
# [array([1., 2., 3.])]
# ______________________________
# iteraçao
# 2
# [3. 8. 9.]
# [array([1. , 3.5, 5. ])]
# [0]
# 1
# [array([1.66666667, 5.        , 6.33333333])]
# [array([1., 2., 3.])]
# ______________________________
# CPU times: user 3.13 s, sys: 11.9 ms, total: 3.14 s
# Wall time: 3.17 s
# ([array([1., 2., 3.])],
#  [array([1.66666667, 5.        , 6.33333333])],
#  [81.0],
#  [3],
#  [102],
#  1)

# %%
def chessboard_division_std(Uniquesample, MMtypicality, interval1, interval2, distancetype):
    L, W = Uniquesample.shape
    if distancetype == 'euclidean':
        W = 1

    BOX = [Uniquesample[k] for k in range(W)]
    BOX_miu = [Uniquesample[k] for k in range(W)]
    BOX_S = [1]*W
    BOX_X = [sum(Uniquesample[k]**2) for k in range(W)]
    NB = W
    BOXMT = [MMtypicality[k] for k in range(W)]

    for i in range(W,L):
        print('Iteraçao',i)
        print('Uniquesample[i]',Uniquesample[i])
        print('BOX_miu',BOX_miu)
        if distancetype == 'minkowski':
            a = cdist(Uniquesample[i].reshape(1,-1), BOX_miu, metric=distancetype, p=1.5)
        else:
            a = cdist(Uniquesample[i].reshape(1,-1), BOX_miu, metric=distancetype)

        b = np.sqrt(cdist(Uniquesample[i].reshape(1,-1), BOX_miu, metric='cosine'))
        distance = np.array([a[0],b[0]]).T
        
        print('a',a)
        print('type a',type(a))
        print('np.shape a',np.shape(a))
        
        print('b',b)
        print('type b',type(b))
        print('np.shape b',np.shape(b))

        print('distance',distance)
        print('type distance',type(distance))
        print('np.shape distance',np.shape(distance))
        
        SQ = []
        for j,d in enumerate(distance):
            if d[0] < interval1 and d[1] < interval2:
                SQ.append(j)
                
        print('SQ',SQ)
        print('type SQ',type(SQ))
        print('np.shape SQ',np.shape(SQ))
        
        COUNT = len(SQ)
        if COUNT == 0:
            BOX.append(Uniquesample[i])
            NB = NB + 1
            BOX_S.append(1)
            BOX_miu.append(Uniquesample[i])
            BOX_X.append(sum(Uniquesample[i]**2))
            BOXMT.append(MMtypicality[i])
        if COUNT >= 1:
            DIS = distance[SQ[::],0]/interval1 + distance[SQ[::],1]/interval2 # pylint: disable=E1136  # pylint/issues/3139
            print('DIS',DIS)
            print('type DIS',type(DIS))
            print('np.shape DIS',np.shape(DIS))
            b = np.argmin(DIS)
            BOX_S[SQ[b]] = BOX_S[SQ[b]] + 1
            BOX_miu[SQ[b]] = (BOX_S[SQ[b]]-1)/BOX_S[SQ[b]]*BOX_miu[SQ[b]] + Uniquesample[i]/BOX_S[SQ[b]]
            BOX_X[SQ[b]] = (BOX_S[SQ[b]]-1)/BOX_S[SQ[b]]*BOX_X[SQ[b]] + sum(Uniquesample[i]**2)/BOX_S[SQ[b]]
            BOXMT[SQ[b]] = BOXMT[SQ[b]] + MMtypicality[i]
        print('_'*30)
    return BOX, BOX_miu, BOX_X, BOX_S, BOXMT, NB

# %%
# %%time
chessboard_division_std(Uniquesample, MMtypicality, interval1, interval2, distancetype)
# Out:
# Iteraçao 1
# Uniquesample[i] [1. 5. 7.]
# BOX_miu [array([1.66666667, 5.        , 6.33333333])]
# a [[0.94280904]]
# type a <class 'numpy.ndarray'>
# np.shape a (1, 1)
# b [[0.07062499]]
# type b <class 'numpy.ndarray'>
# np.shape b (1, 1)
# distance [[0.94280904 0.07062499]]
# type distance <class 'numpy.ndarray'>
# np.shape distance (1, 2)
# SQ [0]
# type SQ <class 'list'>
# np.shape SQ (1,)
# DIS [0.20852146]
# type DIS <class 'numpy.ndarray'>
# np.shape DIS (1,)
# ______________________________
# Iteraçao 2
# Uniquesample[i] [3. 8. 9.]
# BOX_miu [array([1.33333333, 5.        , 6.66666667])]
# a [[4.14996653]]
# type a <class 'numpy.ndarray'>
# np.shape a (1, 1)
# b [[0.08344749]]
# type b <class 'numpy.ndarray'>
# np.shape b (1, 1)
# distance [[4.14996653 0.08344749]]
# type distance <class 'numpy.ndarray'>
# np.shape distance (1, 2)
# SQ [0]
# type SQ <class 'list'>
# np.shape SQ (1,)
# DIS [0.68849818]
# type DIS <class 'numpy.ndarray'>
# np.shape DIS (1,)
# ______________________________
# CPU times: user 41.4 ms, sys: 4.13 ms, total: 45.6 ms
# Wall time: 39.3 ms
# ([array([1.66666667, 5.        , 6.33333333])],
#  [array([1.88888889, 6.        , 7.44444444])],
#  [98.96296296296296],
#  [3],
#  [102],
#  1)

# %%
DIS = [5,4,-1,2,1]
b = 0
mini = DIS[0]
for ii in range(1,len(DIS)):
    if DIS[ii] < mini:
        mini = DIS[ii]
        b = ii
    print(b)
# Out:
# 1
# 2
# 2
# 2
